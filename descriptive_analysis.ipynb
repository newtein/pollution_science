# %%
from combine_data import CombineData
import matplotlib.pyplot as plt
import seaborn as sns
from create_data_for_r_pipelined import RDataCreationPipeline
from combine_multiple_pollutants import CombineMultiplePollutants
import numpy as np

# %%
pollutants = ["PM2", "PM10", "O3"]
state_code = "06"
county_code =["111", "037"]

# %%
box_plot_data = {}
for p in pollutants:
    df = CombineData(p, start_date="22-01-2020", end_date="30-04-2020").get_pandas_obj()
    df = df[df['State Code']==state_code]
    df = df[df['County Code'].isin(county_code)]
    box_plot_data[p] = df['First Max Value'].tolist()
    print(df['Units Of Measure'].iloc[1])

# %%
df['Units Of Measure'].iloc[1]

# %%
units = ['Micrograms/cubic meter (LC)','Micrograms/cubic meter (25 C)', 'Parts per million' ]
sns.set_style('whitegrid')
for index, p in enumerate(pollutants):
    sns.boxplot(box_plot_data[p], sym='')
    plt.title(p)
    plt.xlabel(units[index])
    plt.savefig('manuscript_images/desc_stat_{}.png'.format(p), dpi=600)
    plt.show()

# %%
mat_df = RDataCreationPipeline("PM2", "0-7").mat_df
mat_df = mat_df[(mat_df['date'] >= "22-01-2020") & (mat_df['date'] <= "30-04-2020")]
mat_df
# Out:
# WIND Knots
# TEMP Degrees Fahrenheit
# RH Percent relative humidity
# Pressue Millibars
# Common cities in 06 state: {'San Bernardino', 'Los Angeles', 'San Diego', 'Inyo', 'Ventura'}
# D:\CovidPollution\create_data_for_r_pipelined.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   tdf['date_number'] = list(range(1, tdf.shape[0] + 1))
# r_files/source_file_SA4/R_data_PM2_06_0-7_COVID_mortality.csv & r_files/source_file_SA4/R_data_PM2_06_0-7_COVID_cases.csv written for PM2 at lag 0-7.
#           date       county  mean_pressure    mean_rh  mean_temp  mean_wind  \
# 42  2020-01-22  Los Angeles     933.333333  58.625000  53.754167   4.175000
# 43  2020-01-22      Ventura     987.583333  81.083333  54.625000   4.675000
# 44  2020-01-23  Los Angeles     933.750000  63.125000  49.966667   1.858333
# 45  2020-01-23      Ventura     985.708333  66.909091  64.375000   7.483333
# 46  2020-01-24  Los Angeles     930.166667  55.208333  52.495833   3.029167
# 47  2020-01-24      Ventura     982.666667  61.875000  63.083333   5.158333
# 48  2020-01-25  Los Angeles     931.500000  50.500000  52.825000   1.791667
# 49  2020-01-25      Ventura     984.041667  79.625000  62.625000   6.258333
# 50  2020-01-26  Los Angeles     932.041667  61.500000  51.858333   4.158333
# 51  2020-01-26      Ventura     987.208333  84.666667  54.458333   4.083333
# 52  2020-01-27  Los Angeles     936.166667  54.916667  52.995833   3.658333
# 53  2020-01-27      Ventura     988.958333  65.333333  63.041667   6.712500
# 54  2020-01-28  Los Angeles     934.250000  49.666667  50.775000   5.120833
# 55  2020-01-28      Ventura     987.041667  53.458333  63.833333   6.912500
# 56  2020-01-29  Los Angeles     931.916667  38.833333  51.741667   4.412500
# 57  2020-01-29      Ventura     984.416667  51.375000  60.416667   7.891667
# 58  2020-01-30  Los Angeles     933.958333  34.500000  49.816667   2.025000
# 59  2020-01-30      Ventura     986.291667  47.875000  64.375000   6.845833
# 60  2020-01-31  Los Angeles     938.291667  46.125000  51.100000   2.133333
# 61  2020-01-31      Ventura     989.875000  52.625000  69.375000   9.983333
# 62  2020-02-01  Los Angeles     937.583333  48.166667  53.612500   1.716667
# 63  2020-02-01      Ventura     988.583333  48.208333  71.833333   9.620833
# 64  2020-02-02  Los Angeles     926.250000  51.875000  50.762500   5.908333
# 65  2020-02-02      Ventura     980.000000  71.375000  59.166667   6.208333
# 66  2020-02-03  Los Angeles     926.583333  33.833333  39.975000   4.729167
# 67  2020-02-03      Ventura     980.541667  34.541667  50.708333  12.550000
# 68  2020-02-04  Los Angeles     932.916667  21.708333  36.070833   3.887500
# 69  2020-02-04      Ventura     986.875000  36.541667  49.958333  10.750000
# 70  2020-02-05  Los Angeles     932.916667  25.583333  41.983333   1.708333
# 71  2020-02-05      Ventura     987.666667  49.916667  50.083333   5.787500
# ..         ...          ...            ...        ...        ...        ...
# 182 2020-04-01      Ventura     977.875000  76.000000  60.875000   5.158333
# 183 2020-04-02      Ventura     980.708333  74.250000  57.750000   4.987500
# 184 2020-04-03      Ventura     980.333333  66.208333  55.708333   5.700000
# 185 2020-04-04      Ventura     978.875000  75.250000  55.208333   5.208333
# 186 2020-04-05      Ventura     977.916667  83.958333  55.541667   5.600000
# 187 2020-04-06      Ventura     979.250000  80.833333  55.083333   5.720833
# 188 2020-04-07      Ventura     982.458333  79.958333  51.541667   5.466667
# 189 2020-04-08      Ventura     982.833333  78.583333  52.583333   3.950000
# 190 2020-04-09      Ventura     985.000000  87.750000  51.041667   5.383333
# 191 2020-04-10      Ventura     981.916667  76.250000  55.083333   6.183333
# 192 2020-04-11      Ventura     981.458333  76.416667  57.750000   5.029167
# 193 2020-04-12      Ventura     984.083333  87.791667  57.333333   4.133333
# 194 2020-04-13      Ventura     986.000000  80.750000  57.791667   4.737500
# 195 2020-04-14      Ventura     986.416667  72.583333  63.250000   7.766667
# 196 2020-04-15      Ventura     983.291667  57.458333  65.375000   6.629167
# 197 2020-04-16      Ventura     979.916667  74.041667  63.368421   5.521053
# 198 2020-04-17      Ventura     981.333333  71.958333  59.333333   4.408333
# 199 2020-04-18      Ventura     984.083333  76.041667  58.750000   5.620833
# 200 2020-04-19      Ventura     984.000000  77.541667  58.500000   5.183333
# 201 2020-04-20      Ventura     984.458333  79.000000  58.833333   5.187500
# 202 2020-04-21      Ventura     985.125000  73.791667  61.750000   4.366667
# 203 2020-04-22      Ventura     985.416667  65.250000  71.541667   5.887500
# 204 2020-04-23      Ventura     981.250000  55.500000  79.041667   9.808333
# 205 2020-04-24      Ventura     980.333333  47.291667  81.333333   8.487500
# 206 2020-04-25      Ventura     980.750000  57.500000  77.208333   7.262500
# 207 2020-04-26      Ventura     980.666667  71.250000  72.708333   5.337500
# 208 2020-04-27      Ventura     981.416667  71.416667  70.125000   5.712500
# 209 2020-04-28      Ventura     981.708333  75.458333  71.450000   6.004167
# 210 2020-04-29      Ventura     981.875000  85.791667  68.684211   6.012500
# 211 2020-04-30      Ventura     979.833333  80.416667  68.125000   5.729167
#
#      city  date_number
# 42      1           22
# 43      2           22
# 44      1           23
# 45      2           23
# 46      1           24
# 47      2           24
# 48      1           25
# 49      2           25
# 50      1           26
# 51      2           26
# 52      1           27
# 53      2           27
# 54      1           28
# 55      2           28
# 56      1           29
# 57      2           29
# 58      1           30
# 59      2           30
# 60      1           31
# 61      2           31
# 62      1           32
# 63      2           32
# 64      1           33
# 65      2           33
# 66      1           34
# 67      2           34
# 68      1           35
# 69      2           35
# 70      1           36
# 71      2           36
# ..    ...          ...
# 182     2           92
# 183     2           93
# 184     2           94
# 185     2           95
# 186     2           96
# 187     2           97
# 188     2           98
# 189     2           99
# 190     2          100
# 191     2          101
# 192     2          102
# 193     2          103
# 194     2          104
# 195     2          105
# 196     2          106
# 197     2          107
# 198     2          108
# 199     2          109
# 200     2          110
# 201     2          111
# 202     2          112
# 203     2          113
# 204     2          114
# 205     2          115
# 206     2          116
# 207     2          117
# 208     2          118
# 209     2          119
# 210     2          120
# 211     2          121
#
# [170 rows x 8 columns]

# %%
pollutants = ["PM2", "PM10", "O3"]
df = CombineMultiplePollutants(pollutants,  year=2020, state_code="06", filter_city_list=["037", "111"]).combine_pollutants()
# Out:
# PM2 Micrograms/cubic meter (LC)
# PM10 Micrograms/cubic meter (25 C)
# O3 Parts per million

# %%
df = df.merge(mat_df, on=('date', 'county'))
df.drop(['date_number', 'city', 'date'], axis=1, inplace=True)

# %%
des_stats =  df.describe()
des_stats.columns = ['PM 2.5', 'PM 10', 'O3', 'Pressure', 'RH', 'Temperature','Wind']
des_stats.to_csv("manuscript_images/table_1.csv")

# %%
df.drop(['county'], inplace=True, axis=1)
df.columns = ['PM 2.5', 'PM 10', 'O3', 'Pressure', 'RH', 'Temperature','Wind']

# %%
plt.close()
corr = df.corr(method='spearman')
mask = np.triu(np.ones_like(corr, dtype=np.bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = plt.get_cmap("GnBu")
sns.heatmap(corr, annot=True, cmap=cmap, mask=mask,  cbar_kws={"shrink": .5}, vmax=1, vmin=-1)
plt.savefig("manuscript_images/des_analysis_corr.png", dpi=600, bbox_inches='tight')
plt.show()
